# %% [markdown]
# # Optimiser Solver

# %% [markdown]
# [fgpaconvnet-optimiser](https://github.com/AlexMontgomerie/fpgaconvnet-optimiser) introduces [`Solver`](https://github.com/AlexMontgomerie/fpgaconvnet-optimiser/tree/dev-petros/fpgaconvnet/optimiser/solvers) to automatically apply the `transform`s and explore the design space. Let's still start DSE with the "resource-minimal" status.

# %%
from fpgaconvnet.parser.Parser import Parser

onnx_path = "../3.1_model_onnx_parser/fp16/vgg16_bn.onnx"
parser = Parser(custom_onnx=True, batch_size=1)
net = parser.onnx_to_fpgaconvnet(onnx_path)
# Out:
# CRITICAL WARNING: node Flatten_31 is skipped in hardware

# %%
import fpgaconvnet.optimiser.transforms as transforms

transforms.partition.split_complete(net, None)
for i, partition in enumerate(net.partitions):
    transforms.weights_reloading.apply_max_weights_reloading(partition)
    partition.update()

# %% [markdown]
# To create a new [`Solver`](https://github.com/AlexMontgomerie/fpgaconvnet-optimiser/tree/dev-petros/fpgaconvnet/optimiser/solvers) object, it requires two inputs: [`Network`](https://github.com/AlexMontgomerie/fpgaconvnet-model/blob/dev-petros/fpgaconvnet/models/network/Network.py) and [`Platform`](https://github.com/AlexMontgomerie/fpgaconvnet-model/blob/dev-petros/fpgaconvnet/platform/Platform.py) where the latter spcifies the characteristics of the target FPGA device (resources and bandwidth avaiable, target clock frequency, and etc.).

# %% [markdown]
# In this example, let's target the deployment on a [`ZCU104`](https://www.xilinx.com/products/boards-and-kits/zcu104.html) device.

# %%
from fpgaconvnet.platform.Platform import Platform

platform = Platform()
platform.update("../../fpgaconvnet-optimiser/examples/platforms/zcu104.toml")
# We select port width 64 in this example
platform.port_width = 64

# %% [markdown]
# Currently, we provide two variants of `Solver`: [simulated_anneanling](https://github.com/AlexMontgomerie/fpgaconvnet-optimiser/blob/dev-petros/fpgaconvnet/optimiser/solvers/simulated_annealing.py) and [greedy_partition](https://github.com/AlexMontgomerie/fpgaconvnet-optimiser/blob/dev-petros/fpgaconvnet/optimiser/solvers/greedy_partition.py).

# %% [markdown]
# [simulated_anneanling](https://github.com/AlexMontgomerie/fpgaconvnet-optimiser/blob/dev-petros/fpgaconvnet/optimiser/solvers/simulated_annealing.py) is a well-known stochastic optimisation algorithm. Inside its main optimization loop, a random change is performed to the accelerator configuratoin in each iteration. To use the [simulated_anneanling](https://github.com/AlexMontgomerie/fpgaconvnet-optimiser/blob/dev-petros/fpgaconvnet/optimiser/solvers/simulated_annealing.py) solver, please run the following code, which might take several minutes.

# %%
import pathlib
from fpgaconvnet.optimiser.solvers import SimulatedAnnealing

opt = SimulatedAnnealing(net, platform)
opt.bram_to_lut = False
opt.off_chip_streaming = False
opt.balance_bram_uram = False
opt.rsc_allocation = 0.75


opt.run_solver()
opt.update_partitions()

pathlib.Path("sa").mkdir(parents=True, exist_ok=True)
opt.create_report("sa/report.json")
opt.net.save_all_partitions("sa/config.json")
# Out:
# create edge ('Conv_19', 'Relu_20')
# create edge ('Conv_12', 'Relu_13')
# create edge ('Relu_6', 'Conv_7')
# create edge ('Relu_11', 'Conv_12')
# create edge ('Relu_35', 'Gemm_36')
# create edge ('Relu_13', 'Conv_14')
# create edge ('Conv_7', 'Relu_8')
# create edge ('Conv_17', 'Relu_18')
# ╔══════════════╦════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 10 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 36 ║
# ╚══════════════╩════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |          |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM     | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.148304 (throughput) |    | 0.00/96      | 4.08/624 | 0.47/1728 | 1563.28/230400 | 1039.94/460800 | 3.51/153.6 | 2.07/153.6 | 1.44/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 0.65 %   | 0.03 %    | 0.68 %         | 0.23 %         | 2.29 %     | 1.35 %     | 0.94 %     | 0.00 %     |
#
# create edge ('Conv_2', 'Relu_3')
# create edge ('Relu_15', 'MaxPool_16')
# create edge ('Relu_8', 'MaxPool_9')
# ╔══════════════╦═════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 9.7 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 33 ║
# ╚══════════════╩═════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |          |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM     | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.161564 (throughput) |    | 0.00/96      | 4.48/624 | 0.58/1728 | 3047.30/230400 | 1446.70/460800 | 3.26/153.6 | 1.98/153.6 | 1.28/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 0.72 %   | 0.03 %    | 1.32 %         | 0.31 %         | 2.12 %     | 1.29 %     | 0.83 %     | 0.00 %     |
#
# ╔══════════════╦═══════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 9.409 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 33 ║
# ╚══════════════╩═══════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.162049 (throughput) |    | 0.00/96      | 14.55/624 | 0.58/1728 | 3053.18/230400 | 1447.94/460800 | 3.24/153.6 | 1.97/153.6 | 1.28/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 2.33 %    | 0.03 %    | 1.33 %         | 0.31 %         | 2.11 %     | 1.28 %     | 0.83 %     | 0.00 %     |
#
# create edge ('Conv_12', 'Relu_13')
# create edge ('Conv_14', 'Relu_15')
# create edge ('GlobalMaxPool_30', 'Gemm_32')
# create edge ('Relu_1', 'Conv_2')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 9.12673 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 31 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.179641 (throughput) |    | 0.00/96      | 20.90/624 | 0.77/1728 | 3277.74/230400 | 1568.71/460800 | 3.34/153.6 | 2.00/153.6 | 1.35/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 3.35 %    | 0.04 %    | 1.42 %         | 0.34 %         | 2.18 %     | 1.30 %     | 0.88 %     | 0.00 %     |
#
# create edge ('Conv_17', 'Relu_18')
# create edge ('Relu_3', 'MaxPool_4')
# create edge ('Conv_14', 'Relu_15')
# create edge ('MaxPool_9', 'Conv_10')
# create edge ('Relu_20', 'Conv_21')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 8.85293 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 30 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.182468 (throughput) |    | 0.00/96      | 21.83/624 | 1.30/1728 | 3514.37/230400 | 1722.80/460800 | 4.85/153.6 | 3.56/153.6 | 1.29/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 3.50 %    | 0.08 %    | 1.53 %         | 0.37 %         | 3.15 %     | 2.32 %     | 0.84 %     | 0.00 %     |
#
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 8.58734 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 30 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.195971 (throughput) |    | 0.00/96      | 21.43/624 | 1.57/1728 | 3411.37/230400 | 1693.90/460800 | 4.75/153.6 | 3.46/153.6 | 1.29/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 3.43 %    | 0.09 %    | 1.48 %         | 0.37 %         | 3.09 %     | 2.26 %     | 0.84 %     | 0.00 %     |
#
# create edge ('Conv_26', 'Relu_27')
# create edge ('Relu_6', 'Conv_7')
# create edge ('Relu_11', 'Conv_12')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 8.32972 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 30 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.195971 (throughput) |    | 0.00/96      | 21.43/624 | 1.57/1728 | 3411.37/230400 | 1693.90/460800 | 4.75/153.6 | 3.46/153.6 | 1.29/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 3.43 %    | 0.09 %    | 1.48 %         | 0.37 %         | 3.09 %     | 2.26 %     | 0.84 %     | 0.00 %     |
#
# create edge ('Conv_12', 'Relu_13')
# create edge ('Relu_6', 'Conv_7')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 8.07983 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 28 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.211016 (throughput) |    | 0.00/96      | 18.54/624 | 3.29/1728 | 4628.36/230400 | 2372.75/460800 | 4.67/153.6 | 3.64/153.6 | 1.04/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 2.97 %    | 0.19 %    | 2.01 %         | 0.51 %         | 3.04 %     | 2.37 %     | 0.68 %     | 0.00 %     |
#
# create edge ('Relu_18', 'Conv_19')
# create edge ('Relu_13', 'Conv_14')
# create edge ('Conv_0', 'Relu_1')
# create edge ('Conv_7', 'Relu_8')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 7.83743 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 28 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.211016 (throughput) |    | 0.00/96      | 18.54/624 | 3.29/1728 | 4628.36/230400 | 2372.75/460800 | 4.67/153.6 | 3.64/153.6 | 1.04/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 2.97 %    | 0.19 %    | 2.01 %         | 0.51 %         | 3.04 %     | 2.37 %     | 0.68 %     | 0.00 %     |
#
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 7.60231 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 28 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.203271 (throughput) |    | 0.00/96      | 27.64/624 | 3.50/1728 | 4524.07/230400 | 2336.57/460800 | 4.65/153.6 | 3.61/153.6 | 1.04/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 4.43 %    | 0.20 %    | 1.96 %         | 0.51 %         | 3.03 %     | 2.35 %     | 0.68 %     | 0.00 %     |
#
# create edge ('Conv_10', 'Relu_11')
# create edge ('Conv_0', 'Relu_1')
# create edge ('Relu_29', 'GlobalMaxPool_30')
# create edge ('Relu_3', 'MaxPool_4')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 7.37424 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 24 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.202061 (throughput) |    | 0.00/96      | 21.83/624 | 5.21/1728 | 5328.12/230400 | 2794.21/460800 | 4.86/153.6 | 3.96/153.6 | 0.91/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 3.50 %    | 0.30 %    | 2.31 %         | 0.61 %         | 3.17 %     | 2.58 %     | 0.59 %     | 0.00 %     |
#
# create edge ('Conv_7', 'Relu_8')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 7.15301 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 24 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.202061 (throughput) |    | 0.00/96      | 21.83/624 | 5.21/1728 | 5328.12/230400 | 2794.21/460800 | 4.86/153.6 | 3.96/153.6 | 0.91/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 3.50 %    | 0.30 %    | 2.31 %         | 0.61 %         | 3.17 %     | 2.58 %     | 0.59 %     | 0.00 %     |
#
# create edge ('Conv_14', 'Relu_15')
# create edge ('Relu_18', 'Conv_19')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 6.93842 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 24 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.202061 (throughput) |    | 0.00/96      | 21.83/624 | 5.21/1728 | 5328.12/230400 | 2794.21/460800 | 4.86/153.6 | 3.96/153.6 | 0.91/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 3.50 %    | 0.30 %    | 2.31 %         | 0.61 %         | 3.17 %     | 2.58 %     | 0.59 %     | 0.00 %     |
#
# create edge ('Conv_26', 'Relu_27')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 6.73027 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 24 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.202061 (throughput) |    | 0.00/96      | 21.83/624 | 5.21/1728 | 5328.12/230400 | 2794.21/460800 | 4.86/153.6 | 3.96/153.6 | 0.91/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 3.50 %    | 0.30 %    | 2.31 %         | 0.61 %         | 3.17 %     | 2.58 %     | 0.59 %     | 0.00 %     |
#
# create edge ('MaxPool_4', 'Conv_5')
# create edge ('Conv_17', 'Relu_18')
# create edge ('Relu_22', 'MaxPool_23')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 6.52836 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 24 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.202061 (throughput) |    | 0.00/96      | 21.83/624 | 5.21/1728 | 5328.12/230400 | 2794.21/460800 | 4.86/153.6 | 3.96/153.6 | 0.91/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 3.50 %    | 0.30 %    | 2.31 %         | 0.61 %         | 3.17 %     | 2.58 %     | 0.59 %     | 0.00 %     |
#
# create edge ('Conv_17', 'Relu_18')
# create edge ('Gemm_32', 'Relu_33')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 6.33251 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 24 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.202061 (throughput) |    | 0.00/96      | 21.83/624 | 5.21/1728 | 5328.12/230400 | 2794.21/460800 | 4.86/153.6 | 3.96/153.6 | 0.91/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 3.50 %    | 0.30 %    | 2.31 %         | 0.61 %         | 3.17 %     | 2.58 %     | 0.59 %     | 0.00 %     |
#
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 6.14254 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 25 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.198345 (throughput) |    | 0.00/96      | 23.24/624 | 5.00/1728 | 5164.88/230400 | 2688.12/460800 | 3.66/153.6 | 2.28/153.6 | 1.38/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 3.72 %    | 0.29 %    | 2.24 %         | 0.58 %         | 2.38 %     | 1.48 %     | 0.90 %     | 0.00 %     |
#
# create edge ('MaxPool_16', 'Conv_17')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 5.95826 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 24 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.219789 (throughput) |    | 0.00/96      | 27.08/624 | 4.21/1728 | 5497.75/230400 | 2810.62/460800 | 3.32/153.6 | 1.91/153.6 | 1.41/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 4.34 %    | 0.24 %    | 2.39 %         | 0.61 %         | 2.16 %     | 1.24 %     | 0.92 %     | 0.00 %     |
#
# create edge ('Relu_25', 'Conv_26')
# create edge ('Relu_11', 'Conv_12')
# create edge ('Relu_22', 'MaxPool_23')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 5.77951 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 23 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.224346 (throughput) |    | 0.00/96      | 25.78/624 | 4.39/1728 | 5685.87/230400 | 2931.26/460800 | 3.72/153.6 | 2.39/153.6 | 1.33/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 4.13 %    | 0.25 %    | 2.47 %         | 0.64 %         | 2.42 %     | 1.56 %     | 0.87 %     | 0.00 %     |
#
# create edge ('Relu_25', 'Conv_26')
# create edge ('Relu_25', 'Conv_26')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 5.60613 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 22 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.254124 (throughput) |    | 0.00/96      | 34.68/624 | 4.59/1728 | 5946.82/230400 | 3064.77/460800 | 3.60/153.6 | 2.35/153.6 | 1.25/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.56 %    | 0.27 %    | 2.58 %         | 0.67 %         | 2.34 %     | 1.53 %     | 0.81 %     | 0.00 %     |
#
# create edge ('Relu_35', 'Gemm_36')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 5.43794 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 22 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.254124 (throughput) |    | 0.00/96      | 34.68/624 | 4.59/1728 | 5946.82/230400 | 3064.77/460800 | 3.60/153.6 | 2.35/153.6 | 1.25/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.56 %    | 0.27 %    | 2.58 %         | 0.67 %         | 2.34 %     | 1.53 %     | 0.81 %     | 0.00 %     |
#
# create edge ('Relu_13', 'Conv_14')
# create edge ('MaxPool_4', 'Conv_5')
# ╔══════════════╦════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 5.2748 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 22 ║
# ╚══════════════╩════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.254124 (throughput) |    | 0.00/96      | 34.68/624 | 4.59/1728 | 5946.82/230400 | 3064.77/460800 | 3.60/153.6 | 2.35/153.6 | 1.25/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.56 %    | 0.27 %    | 2.58 %         | 0.67 %         | 2.34 %     | 1.53 %     | 0.81 %     | 0.00 %     |
#
# create edge ('Relu_35', 'Gemm_36')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 5.11656 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 22 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.254124 (throughput) |    | 0.00/96      | 34.68/624 | 4.59/1728 | 5946.82/230400 | 3064.77/460800 | 3.60/153.6 | 2.35/153.6 | 1.25/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.56 %    | 0.27 %    | 2.58 %         | 0.67 %         | 2.34 %     | 1.53 %     | 0.81 %     | 0.00 %     |
#
# create edge ('Relu_18', 'Conv_19')
# create edge ('Conv_28', 'Relu_29')
# create edge ('Conv_21', 'Relu_22')
# create edge ('Gemm_32', 'Relu_33')
# create edge ('Conv_19', 'Relu_20')
# create edge ('MaxPool_4', 'Conv_5')
# create edge ('Relu_33', 'Gemm_34')
# create edge ('Relu_6', 'Conv_7')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 4.96306 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 22 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.254124 (throughput) |    | 0.00/96      | 34.68/624 | 4.59/1728 | 5946.82/230400 | 3064.77/460800 | 3.60/153.6 | 2.35/153.6 | 1.25/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.56 %    | 0.27 %    | 2.58 %         | 0.67 %         | 2.34 %     | 1.53 %     | 0.81 %     | 0.00 %     |
#
# create edge ('Relu_11', 'Conv_12')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 4.81417 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 22 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.254124 (throughput) |    | 0.00/96      | 34.68/624 | 4.59/1728 | 5946.82/230400 | 3064.77/460800 | 3.60/153.6 | 2.35/153.6 | 1.25/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.56 %    | 0.27 %    | 2.58 %         | 0.67 %         | 2.34 %     | 1.53 %     | 0.81 %     | 0.00 %     |
#
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 4.66975 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 22 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.253991 (throughput) |    | 0.00/96      | 36.14/624 | 3.14/1728 | 5827.05/230400 | 2912.68/460800 | 3.54/153.6 | 2.30/153.6 | 1.24/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.79 %    | 0.18 %    | 2.53 %         | 0.63 %         | 2.31 %     | 1.50 %     | 0.81 %     | 0.00 %     |
#
# create edge ('Gemm_34', 'Relu_35')
# create edge ('Relu_18', 'Conv_19')
# create edge ('Relu_33', 'Gemm_34')
# create edge ('Conv_14', 'Relu_15')
# create edge ('Relu_18', 'Conv_19')
# create edge ('MaxPool_9', 'Conv_10')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 4.52965 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 22 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.253991 (throughput) |    | 0.00/96      | 36.14/624 | 3.14/1728 | 5827.05/230400 | 2912.68/460800 | 3.54/153.6 | 2.30/153.6 | 1.24/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.79 %    | 0.18 %    | 2.53 %         | 0.63 %         | 2.31 %     | 1.50 %     | 0.81 %     | 0.00 %     |
#
# create edge ('MaxPool_23', 'Conv_24')
# create edge ('Relu_33', 'Gemm_34')
# create edge ('Relu_35', 'Gemm_36')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 4.39377 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 19 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.282100 (throughput) |    | 0.00/96      | 35.53/624 | 3.74/1728 | 6921.89/230400 | 3502.79/460800 | 2.97/153.6 | 1.91/153.6 | 1.06/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.69 %    | 0.22 %    | 3.00 %         | 0.76 %         | 1.93 %     | 1.24 %     | 0.69 %     | 0.00 %     |
#
# create edge ('Conv_17', 'Relu_18')
# create edge ('Conv_19', 'Relu_20')
# create edge ('Conv_26', 'Relu_27')
# create edge ('Conv_28', 'Relu_29')
# create edge ('Relu_18', 'Conv_19')
# create edge ('Gemm_34', 'Relu_35')
# create edge ('Conv_17', 'Relu_18')
# create edge ('Gemm_32', 'Relu_33')
# create edge ('Gemm_34', 'Relu_35')
# create edge ('Relu_6', 'Conv_7')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 4.26195 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 19 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |           |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|-----------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP       | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.282100 (throughput) |    | 0.00/96      | 35.53/624 | 3.74/1728 | 6921.89/230400 | 3502.79/460800 | 2.97/153.6 | 1.91/153.6 | 1.06/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.69 %    | 0.22 %    | 3.00 %         | 0.76 %         | 1.93 %     | 1.24 %     | 0.69 %     | 0.00 %     |
#
# create edge ('Conv_5', 'Relu_6')
# create edge ('MaxPool_4', 'Conv_5')
# create edge ('Conv_24', 'Relu_25')
# create edge ('Relu_6', 'Conv_7')
# create edge ('Conv_28', 'Relu_29')
# create edge ('Conv_21', 'Relu_22')
# create edge ('Conv_28', 'Relu_29')
# create edge ('Gemm_32', 'Relu_33')
# create edge ('Relu_13', 'Conv_14')
# create edge ('MaxPool_4', 'Conv_5')
# create edge ('Conv_26', 'Relu_27')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 4.13409 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 19 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.294036 (throughput) |    | 0.00/96      | 35.74/624 | 16.63/1728 | 10153.68/230400 | 6001.89/460800 | 3.01/153.6 | 1.95/153.6 | 1.06/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.73 %    | 0.96 %     | 4.41 %          | 1.30 %         | 1.96 %     | 1.27 %     | 0.69 %     | 0.00 %     |
#
# create edge ('Conv_28', 'Relu_29')
# create edge ('Conv_19', 'Relu_20')
# create edge ('Gemm_34', 'Relu_35')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 4.01007 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 19 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.294036 (throughput) |    | 0.00/96      | 35.74/624 | 16.63/1728 | 10153.68/230400 | 6001.89/460800 | 3.01/153.6 | 1.95/153.6 | 1.06/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.73 %    | 0.96 %     | 4.41 %          | 1.30 %         | 1.96 %     | 1.27 %     | 0.69 %     | 0.00 %     |
#
# create edge ('Conv_17', 'Relu_18')
# create edge ('Gemm_34', 'Relu_35')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 3.88977 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 19 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.294036 (throughput) |    | 0.00/96      | 35.74/624 | 16.63/1728 | 10153.68/230400 | 6001.89/460800 | 3.01/153.6 | 1.95/153.6 | 1.06/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.73 %    | 0.96 %     | 4.41 %          | 1.30 %         | 1.96 %     | 1.27 %     | 0.69 %     | 0.00 %     |
#
# create edge ('Conv_5', 'Relu_6')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 3.77308 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 19 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.294036 (throughput) |    | 0.00/96      | 35.74/624 | 16.63/1728 | 10153.68/230400 | 6001.89/460800 | 3.01/153.6 | 1.95/153.6 | 1.06/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.73 %    | 0.96 %     | 4.41 %          | 1.30 %         | 1.96 %     | 1.27 %     | 0.69 %     | 0.00 %     |
#
# create edge ('Conv_26', 'Relu_27')
# create edge ('Conv_17', 'Relu_18')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 3.65988 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 19 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.303453 (throughput) |    | 0.00/96      | 42.47/624 | 17.05/1728 | 9998.84/230400 | 5959.53/460800 | 3.36/153.6 | 2.13/153.6 | 1.23/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 6.81 %    | 0.99 %     | 4.34 %         | 1.29 %         | 2.19 %     | 1.39 %     | 0.80 %     | 0.00 %     |
#
# create edge ('Conv_17', 'Relu_18')
# create edge ('Gemm_34', 'Relu_35')
# create edge ('Conv_7', 'Relu_8')
# create edge ('Relu_13', 'Conv_14')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 3.55009 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 19 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.303453 (throughput) |    | 0.00/96      | 42.47/624 | 17.05/1728 | 9998.84/230400 | 5959.53/460800 | 3.36/153.6 | 2.13/153.6 | 1.23/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 6.81 %    | 0.99 %     | 4.34 %         | 1.29 %         | 2.19 %     | 1.39 %     | 0.80 %     | 0.00 %     |
#
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 3.44358 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 19 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.303453 (throughput) |    | 0.00/96      | 42.47/624 | 17.05/1728 | 9998.84/230400 | 5959.53/460800 | 3.36/153.6 | 2.13/153.6 | 1.23/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 6.81 %    | 0.99 %     | 4.34 %         | 1.29 %         | 2.19 %     | 1.39 %     | 0.80 %     | 0.00 %     |
#
# create edge ('Relu_18', 'Conv_19')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 3.34028 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 18 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.329932 (throughput) |    | 0.00/96      | 43.00/624 | 12.28/1728 | 6842.56/230400 | 3892.17/460800 | 3.11/153.6 | 1.97/153.6 | 1.14/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 6.89 %    | 0.71 %     | 2.97 %         | 0.84 %         | 2.03 %     | 1.28 %     | 0.74 %     | 0.00 %     |
#
# create edge ('MaxPool_9', 'Conv_10')
# create edge ('Conv_14', 'Relu_15')
# create edge ('Conv_14', 'Relu_15')
# create edge ('Relu_20', 'Conv_21')
# create edge ('Conv_17', 'Relu_18')
# create edge ('Gemm_34', 'Relu_35')
# create edge ('Relu_20', 'Conv_21')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 3.24007 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 18 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.329932 (throughput) |    | 0.00/96      | 43.00/624 | 12.28/1728 | 6842.56/230400 | 3892.17/460800 | 3.11/153.6 | 1.97/153.6 | 1.14/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 6.89 %    | 0.71 %     | 2.97 %         | 0.84 %         | 2.03 %     | 1.28 %     | 0.74 %     | 0.00 %     |
#
# create edge ('Conv_19', 'Relu_20')
# create edge ('Gemm_34', 'Relu_35')
# create edge ('Conv_21', 'Relu_22')
# create edge ('Relu_6', 'Conv_7')
# create edge ('MaxPool_4', 'Conv_5')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 3.14287 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 18 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.329932 (throughput) |    | 0.00/96      | 43.00/624 | 12.28/1728 | 6842.56/230400 | 3892.17/460800 | 3.11/153.6 | 1.97/153.6 | 1.14/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 6.89 %    | 0.71 %     | 2.97 %         | 0.84 %         | 2.03 %     | 1.28 %     | 0.74 %     | 0.00 %     |
#
# create edge ('Conv_19', 'Relu_20')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 3.04858 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 18 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.330984 (throughput) |    | 0.00/96      | 56.61/624 | 36.28/1728 | 9084.28/230400 | 5459.11/460800 | 3.24/153.6 | 2.04/153.6 | 1.20/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 9.07 %    | 2.10 %     | 3.94 %         | 1.18 %         | 2.11 %     | 1.33 %     | 0.78 %     | 0.00 %     |
#
# create edge ('Gemm_34', 'Relu_35')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 2.95712 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 18 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.324945 (throughput) |    | 0.00/96      | 77.94/624 | 36.72/1728 | 9275.56/230400 | 5526.50/460800 | 3.22/153.6 | 2.01/153.6 | 1.21/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 12.49 %   | 2.13 %     | 4.03 %         | 1.20 %         | 2.09 %     | 1.31 %     | 0.78 %     | 0.00 %     |
#
# create edge ('Relu_11', 'Conv_12')
# create edge ('Conv_28', 'Relu_29')
# create edge ('Gemm_32', 'Relu_33')
# ╔══════════════╦═════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 2.86841 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 18 ║
# ╚══════════════╩═════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.324945 (throughput) |    | 0.00/96      | 77.94/624 | 36.72/1728 | 9275.56/230400 | 5526.50/460800 | 3.22/153.6 | 2.01/153.6 | 1.21/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 12.49 %   | 2.13 %     | 4.03 %         | 1.20 %         | 2.09 %     | 1.31 %     | 0.78 %     | 0.00 %     |
#
# create edge ('Conv_5', 'Relu_6')
# create edge ('Gemm_32', 'Relu_33')
# ...
# ╚══════════════╩══════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.634972 (throughput) |    | 0.00/96      | 66.73/624 | 68.20/1728 | 45696.33/230400 | 20945.87/460800 | 2.96/153.6 | 2.47/153.6 | 0.49/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 10.69 %   | 3.95 %     | 19.83 %         | 4.55 %          | 1.93 %     | 1.61 %     | 0.32 %     | 0.00 %     |
#
# create edge ('Conv_14', 'Relu_15')
# create edge ('Relu_35', 'Gemm_36')
# create edge ('MaxPool_4', 'Conv_5')
# ╔══════════════╦══════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 0.009935 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 15 ║
# ╚══════════════╩══════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.634972 (throughput) |    | 0.00/96      | 66.73/624 | 68.20/1728 | 45696.33/230400 | 20945.87/460800 | 2.96/153.6 | 2.47/153.6 | 0.49/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 10.69 %   | 3.95 %     | 19.83 %         | 4.55 %          | 1.93 %     | 1.61 %     | 0.32 %     | 0.00 %     |
#
# create edge ('Relu_20', 'Conv_21')
# create edge ('Relu_35', 'Gemm_36')
# create edge ('Relu_27', 'Conv_28')
# ╔══════════════╦══════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 0.009637 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 15 ║
# ╚══════════════╩══════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.634972 (throughput) |    | 0.00/96      | 66.73/624 | 68.20/1728 | 45696.33/230400 | 20945.87/460800 | 2.96/153.6 | 2.47/153.6 | 0.49/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 10.69 %   | 3.95 %     | 19.83 %         | 4.55 %          | 1.93 %     | 1.61 %     | 0.32 %     | 0.00 %     |
#
# create edge ('Relu_35', 'Gemm_36')
# create edge ('Relu_11', 'Conv_12')
# create edge ('Conv_19', 'Relu_20')
# create edge ('Conv_24', 'Relu_25')
# create edge ('Relu_11', 'Conv_12')
# create edge ('MaxPool_4', 'Conv_5')
# create edge ('Conv_12', 'Relu_13')
# create edge ('Conv_17', 'Relu_18')
# create edge ('Relu_35', 'Gemm_36')
# create edge ('Relu_35', 'Gemm_36')
# create edge ('Conv_19', 'Relu_20')
# create edge ('Relu_35', 'Gemm_36')
# create edge ('Conv_26', 'Relu_27')
# ╔══════════════╦══════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 0.009348 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 15 ║
# ╚══════════════╩══════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.634972 (throughput) |    | 0.00/96      | 66.73/624 | 68.20/1728 | 45696.33/230400 | 20945.87/460800 | 2.96/153.6 | 2.47/153.6 | 0.49/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 10.69 %   | 3.95 %     | 19.83 %         | 4.55 %          | 1.93 %     | 1.61 %     | 0.32 %     | 0.00 %     |
#
# create edge ('Conv_21', 'Relu_22')
# ╔══════════════╦══════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 0.009068 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 15 ║
# ╚══════════════╩══════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.635435 (throughput) |    | 0.00/96      | 98.13/624 | 68.20/1728 | 45729.60/230400 | 20946.40/460800 | 2.85/153.6 | 2.35/153.6 | 0.49/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 15.73 %   | 3.95 %     | 19.85 %         | 4.55 %          | 1.85 %     | 1.53 %     | 0.32 %     | 0.00 %     |
#
# create edge ('Conv_26', 'Relu_27')
# create edge ('Relu_35', 'Gemm_36')
# create edge ('Relu_11', 'Conv_12')
# ╔══════════════╦══════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 0.008796 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 15 ║
# ╚══════════════╩══════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.635435 (throughput) |    | 0.00/96      | 98.13/624 | 68.20/1728 | 45729.60/230400 | 20946.40/460800 | 2.85/153.6 | 2.35/153.6 | 0.49/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 15.73 %   | 3.95 %     | 19.85 %         | 4.55 %          | 1.85 %     | 1.53 %     | 0.32 %     | 0.00 %     |
#
# create edge ('Conv_14', 'Relu_15')
# ╔══════════════╦══════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 0.008532 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 15 ║
# ╚══════════════╩══════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.635435 (throughput) |    | 0.00/96      | 98.13/624 | 68.20/1728 | 45729.60/230400 | 20946.40/460800 | 2.85/153.6 | 2.35/153.6 | 0.49/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 15.73 %   | 3.95 %     | 19.85 %         | 4.55 %          | 1.85 %     | 1.53 %     | 0.32 %     | 0.00 %     |
#
# create edge ('Conv_24', 'Relu_25')
# create edge ('Conv_19', 'Relu_20')
# create edge ('Conv_7', 'Relu_8')
# create edge ('Conv_28', 'Relu_29')
# create edge ('Conv_21', 'Relu_22')
# create edge ('Conv_14', 'Relu_15')
# create edge ('Conv_28', 'Relu_29')
# create edge ('Relu_27', 'Conv_28')
# create edge ('Conv_28', 'Relu_29')
# create edge ('Conv_21', 'Relu_22')
# create edge ('Relu_35', 'Gemm_36')
# create edge ('Relu_35', 'Gemm_36')
# create edge ('Conv_28', 'Relu_29')
# create edge ('Conv_24', 'Relu_25')
# create edge ('Conv_7', 'Relu_8')
# create edge ('Relu_27', 'Conv_28')
# create edge ('Relu_35', 'Gemm_36')
# create edge ('Conv_21', 'Relu_22')
# create edge ('Conv_14', 'Relu_15')
# create edge ('Relu_35', 'Gemm_36')
# create edge ('Relu_3', 'MaxPool_4')
# create edge ('Relu_11', 'Conv_12')
# create edge ('MaxPool_4', 'Conv_5')
# create edge ('Relu_35', 'Gemm_36')
# create edge ('MaxPool_4', 'Conv_5')
# create edge ('Conv_14', 'Relu_15')
# create edge ('Relu_27', 'Conv_28')
# create edge ('MaxPool_4', 'Conv_5')
# create edge ('Relu_25', 'Conv_26')
# create edge ('Conv_17', 'Relu_18')
# create edge ('Gemm_32', 'Relu_33')
# create edge ('Conv_14', 'Relu_15')
# ╔══════════════╦══════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 0.008276 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 15 ║
# ╚══════════════╩══════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.635435 (throughput) |    | 0.00/96      | 98.13/624 | 68.20/1728 | 45729.60/230400 | 20946.40/460800 | 2.85/153.6 | 2.35/153.6 | 0.49/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 15.73 %   | 3.95 %     | 19.85 %         | 4.55 %          | 1.85 %     | 1.53 %     | 0.32 %     | 0.00 %     |
#
# create edge ('Gemm_32', 'Relu_33')
# create edge ('Conv_12', 'Relu_13')
# create edge ('Conv_12', 'Relu_13')
# create edge ('Relu_11', 'Conv_12')
# create edge ('Gemm_32', 'Relu_33')
# create edge ('Conv_12', 'Relu_13')
# create edge ('MaxPool_4', 'Conv_5')
# ╔══════════════╦══════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 0.008028 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 15 ║
# ╚══════════════╩══════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.635435 (throughput) |    | 0.00/96      | 98.13/624 | 68.20/1728 | 45729.60/230400 | 20946.40/460800 | 2.85/153.6 | 2.35/153.6 | 0.49/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 15.73 %   | 3.95 %     | 19.85 %         | 4.55 %          | 1.85 %     | 1.53 %     | 0.32 %     | 0.00 %     |
#
# create edge ('Relu_27', 'Conv_28')
# create edge ('Gemm_32', 'Relu_33')
# ╔══════════════╦══════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 0.007787 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 15 ║
# ╚══════════════╩══════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.635435 (throughput) |    | 0.00/96      | 98.13/624 | 68.20/1728 | 45729.60/230400 | 20946.40/460800 | 2.85/153.6 | 2.35/153.6 | 0.49/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 15.73 %   | 3.95 %     | 19.85 %         | 4.55 %          | 1.85 %     | 1.53 %     | 0.32 %     | 0.00 %     |
#
# create edge ('Conv_12', 'Relu_13')
# ╔══════════════╦══════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 0.007553 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 15 ║
# ╚══════════════╩══════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.635435 (throughput) |    | 0.00/96      | 98.13/624 | 68.20/1728 | 45729.60/230400 | 20946.40/460800 | 2.85/153.6 | 2.35/153.6 | 0.49/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 15.73 %   | 3.95 %     | 19.85 %         | 4.55 %          | 1.85 %     | 1.53 %     | 0.32 %     | 0.00 %     |
#
# create edge ('Relu_27', 'Conv_28')
# ╔══════════════╦══════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 0.007327 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 14 ║
# ╚══════════════╩══════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.662261 (throughput) |    | 0.00/96      | 97.14/624 | 70.79/1728 | 49193.07/230400 | 22436.00/460800 | 2.12/153.6 | 2.05/153.6 | 0.07/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 15.57 %   | 4.10 %     | 21.35 %         | 4.87 %          | 1.38 %     | 1.34 %     | 0.05 %     | 0.00 %     |
#
# create edge ('MaxPool_4', 'Conv_5')
# ╔══════════════╦══════════╦══════════════════╦═══════╦══╦═══════════════════════╦════╗
# ║ temperature: ║ 0.007107 ║ Min temperature: ║ 0.007 ║  ║ number of partitions: ║ 14 ║
# ╚══════════════╩══════════╩══════════════════╩═══════╩══╩═══════════════════════╩════╝
# | COST:                 |    | RESOURCES:   |           |            |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.662261 (throughput) |    | 0.00/96      | 97.14/624 | 70.79/1728 | 49193.07/230400 | 22436.00/460800 | 2.12/153.6 | 2.05/153.6 | 0.07/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 15.57 %   | 4.10 %     | 21.35 %         | 4.87 %          | 1.38 %     | 1.34 %     | 0.05 %     | 0.00 %     |

# %% [markdown]
# Alternatively, we provide the [`greedy_partition`](https://github.com/AlexMontgomerie/fpgaconvnet-optimiser/blob/dev-petros/fpgaconvnet/optimiser/solvers/greedy_partition.py) solver which is a deterministic, greedy algorithm that iteratively optimizes the slowest layer in the network

# %%
net = parser.onnx_to_fpgaconvnet(onnx_path)
transforms.partition.split_complete(net, None)
for i, partition in enumerate(net.partitions):
    transforms.weights_reloading.apply_max_weights_reloading(partition)
    partition.update()
# Out:
# CRITICAL WARNING: node Flatten_31 is skipped in hardware

# %%
import pathlib
from fpgaconvnet.optimiser.solvers import GreedyPartition

opt = GreedyPartition(net, platform)
opt.bram_to_lut = False
opt.off_chip_streaming = False
opt.balance_bram_uram = False
opt.rsc_allocation = 0.75
opt.transforms = []
opt.transforms_probs = []


opt.run_solver()
opt.update_partitions()
opt.merge_memory_bound_partitions()
opt.update_partitions()

pathlib.Path("gp").mkdir(parents=True, exist_ok=True)
opt.create_report("gp/report.json")
opt.net.save_all_partitions("gp/config.json")
# Out:
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 1) cost (throughput): ║ 90620.8 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.85 sec ║ total optimisation time: ║ 0.85 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.148526 (throughput) |    | 0.00/96      | 15.61/624 | 24.44/1728 | 2402.92/230400 | 2328.75/460800 | 6.48/153.6 | 2.20/153.6 | 4.28/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 2.50 %    | 1.41 %     | 1.04 %         | 0.51 %         | 4.22 %     | 1.43 %     | 2.79 %     | 0.00 %     |
#
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 2) cost (throughput): ║ 48816.2 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.30 sec ║ total optimisation time: ║ 1.15 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.148533 (throughput) |    | 0.00/96      | 15.61/624 | 24.44/1728 | 2409.58/230400 | 2343.33/460800 | 9.14/153.6 | 3.53/153.6 | 5.61/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 2.50 %    | 1.41 %     | 1.05 %         | 0.51 %         | 5.95 %     | 2.30 %     | 3.65 %     | 0.00 %     |
#
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 3) cost (throughput): ║ 4977.97 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.87 sec ║ total optimisation time: ║ 2.02 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |            |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.153435 (throughput) |    | 0.00/96      | 31.33/624 | 56.42/1728 | 4861.22/230400 | 4549.89/460800 | 9.45/153.6 | 3.68/153.6 | 5.77/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.02 %    | 3.26 %     | 2.11 %         | 0.99 %         | 6.15 %     | 2.40 %     | 3.76 %     | 0.00 %     |
#
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 4) cost (throughput): ║ 48816.2 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.36 sec ║ total optimisation time: ║ 2.38 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |             |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|-------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW          | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.153442 (throughput) |    | 0.00/96      | 31.33/624 | 56.42/1728 | 4867.89/230400 | 4564.47/460800 | 12.12/153.6 | 5.01/153.6 | 7.10/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.02 %    | 3.26 %     | 2.11 %         | 0.99 %         | 7.89 %      | 3.26 %     | 4.62 %     | 0.00 %     |
#
# ╔══════════════════════════════════════════════╦═══════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 5) cost (throughput): ║ 47259 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.33 sec ║ total optimisation time: ║ 2.71 sec ║
# ╚══════════════════════════════════════════════╩═══════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |             |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|-------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW          | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.153450 (throughput) |    | 0.00/96      | 31.50/624 | 56.42/1728 | 4999.25/230400 | 4701.56/460800 | 13.78/153.6 | 6.35/153.6 | 7.44/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 5.05 %    | 3.26 %     | 2.17 %         | 1.02 %         | 8.97 %      | 4.13 %     | 4.84 %     | 0.00 %     |
#
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 6) cost (throughput): ║ 10392.8 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 1.00 sec ║ total optimisation time: ║ 3.71 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |             |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|-------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW          | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.156392 (throughput) |    | 0.00/96      | 47.22/624 | 88.39/1728 | 7452.83/230400 | 6908.14/460800 | 14.04/153.6 | 6.43/153.6 | 7.61/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 7.57 %    | 5.12 %     | 3.23 %         | 1.50 %         | 9.14 %      | 4.18 %     | 4.96 %     | 0.00 %     |
#
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 7) cost (throughput): ║ 97608.6 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.35 sec ║ total optimisation time: ║ 4.06 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |            |                |                |             |            |            |            |
# |-----------------------|----|--------------|-----------|------------|----------------|----------------|-------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP        | LUT            | FF             | BW          | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.156396 (throughput) |    | 0.00/96      | 47.22/624 | 88.39/1728 | 7459.50/230400 | 6922.72/460800 | 16.71/153.6 | 7.76/153.6 | 8.95/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 7.57 %    | 5.12 %     | 3.24 %         | 1.50 %         | 10.88 %     | 5.05 %     | 5.82 %     | 0.00 %     |
#
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 8) cost (throughput): ║ 5129.78 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.87 sec ║ total optimisation time: ║ 4.92 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |             |                |                |             |            |            |            |
# |-----------------------|----|--------------|-----------|-------------|----------------|----------------|-------------|------------|------------|------------|
# |                       |    | URAM         | BRAM      | DSP         | LUT            | FF             | BW          | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.162633 (throughput) |    | 0.00/96      | 63.08/624 | 120.36/1728 | 9912.67/230400 | 9129.19/460800 | 16.88/153.6 | 7.84/153.6 | 9.04/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 10.11 %   | 6.97 %      | 4.30 %         | 1.98 %         | 10.99 %     | 5.11 %     | 5.88 %     | 0.00 %     |
#
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 9) cost (throughput): ║ 97608.6 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.33 sec ║ total optimisation time: ║ 5.25 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |             |                |                |             |            |             |            |
# |-----------------------|----|--------------|-----------|-------------|----------------|----------------|-------------|------------|-------------|------------|
# |                       |    | URAM         | BRAM      | DSP         | LUT            | FF             | BW          | BW_IN      | BW_OUT      | BW_WEIGHT  |
# | 0.162637 (throughput) |    | 0.00/96      | 63.08/624 | 120.36/1728 | 9919.33/230400 | 9143.78/460800 | 19.54/153.6 | 9.17/153.6 | 10.37/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 10.11 %   | 6.97 %      | 4.31 %         | 1.98 %         | 12.72 %     | 5.97 %     | 6.75 %      | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 10) cost (throughput): ║ 91407.7 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.44 sec ║ total optimisation time: ║ 5.69 sec ║
# ╚═══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |             |                 |                |             |             |             |            |
# |-----------------------|----|--------------|-----------|-------------|-----------------|----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM      | DSP         | LUT             | FF             | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.162642 (throughput) |    | 0.00/96      | 63.19/624 | 120.36/1728 | 10050.86/230400 | 9280.89/460800 | 21.21/153.6 | 10.51/153.6 | 10.70/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 10.13 %   | 6.97 %      | 4.36 %          | 2.01 %         | 13.81 %     | 6.84 %      | 6.97 %      | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 11) cost (throughput): ║ 8460.24 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.95 sec ║ total optimisation time: ║ 6.64 sec ║
# ╚═══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|-----------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM      | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.166960 (throughput) |    | 0.00/96      | 79.06/624 | 152.33/1728 | 12507.86/230400 | 11487.36/460800 | 21.34/153.6 | 10.55/153.6 | 10.79/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 12.67 %   | 8.82 %      | 5.43 %          | 2.49 %          | 13.89 %     | 6.87 %      | 7.03 %      | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 12) cost (throughput): ║ 195122 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.35 sec ║ total optimisation time: ║ 6.99 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|-----------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM      | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.166963 (throughput) |    | 0.00/96      | 79.06/624 | 152.33/1728 | 12514.53/230400 | 11501.94/460800 | 24.00/153.6 | 11.88/153.6 | 12.12/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 12.67 %   | 8.82 %      | 5.43 %          | 2.50 %          | 15.63 %     | 7.73 %      | 7.89 %      | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 13) cost (throughput): ║ 4142.5 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 1.03 sec ║ total optimisation time: ║ 8.02 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|-----------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM      | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.176327 (throughput) |    | 0.00/96      | 94.89/624 | 184.31/1728 | 14971.53/230400 | 13708.22/460800 | 24.09/153.6 | 11.92/153.6 | 12.17/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 15.21 %   | 10.67 %     | 6.50 %          | 2.97 %          | 15.68 %     | 7.76 %      | 7.92 %      | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 14) cost (throughput): ║ 195122 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.35 sec ║ total optimisation time: ║ 8.37 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |           |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|-----------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM      | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.176330 (throughput) |    | 0.00/96      | 94.89/624 | 184.31/1728 | 14978.19/230400 | 13722.81/460800 | 26.75/153.6 | 13.25/153.6 | 13.50/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 15.21 %   | 10.67 %     | 6.50 %          | 2.98 %          | 17.42 %     | 8.63 %      | 8.79 %      | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 15) cost (throughput): ║ 4142.5 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 1.04 sec ║ total optimisation time: ║ 9.41 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.186808 (throughput) |    | 0.00/96      | 110.72/624 | 216.28/1728 | 17435.19/230400 | 15929.08/460800 | 26.84/153.6 | 13.29/153.6 | 13.55/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 17.74 %    | 12.52 %     | 7.57 %          | 3.46 %          | 17.47 %     | 8.65 %      | 8.82 %      | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦══════════╗
# ║ single partition (Part 16) cost (throughput): ║ 195122 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.38 sec ║ total optimisation time: ║ 9.79 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.186810 (throughput) |    | 0.00/96      | 110.72/624 | 216.28/1728 | 17441.86/230400 | 15943.67/460800 | 29.50/153.6 | 14.62/153.6 | 14.88/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 17.74 %    | 12.52 %     | 7.57 %          | 3.46 %          | 19.21 %     | 9.52 %      | 9.69 %      | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 17) cost (throughput): ║ 170648 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.38 sec ║ total optimisation time: ║ 10.16 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.186813 (throughput) |    | 0.00/96      | 110.83/624 | 216.28/1728 | 17573.39/230400 | 16080.75/460800 | 31.17/153.6 | 15.96/153.6 | 15.21/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 17.76 %    | 12.52 %     | 7.63 %          | 3.49 %          | 20.29 %     | 10.39 %     | 9.90 %      | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 18) cost (throughput): ║ 5.2522 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.68 sec ║ total optimisation time: ║ 10.85 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.189469 (throughput) |    | 0.00/96      | 125.00/624 | 216.50/1728 | 17497.08/230400 | 16059.06/460800 | 31.17/153.6 | 15.95/153.6 | 15.21/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 20.03 %    | 12.53 %     | 7.59 %          | 3.49 %          | 20.29 %     | 10.39 %     | 9.90 %      | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 19) cost (throughput): ║ 389864 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.38 sec ║ total optimisation time: ║ 11.23 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.189470 (throughput) |    | 0.00/96      | 125.00/624 | 216.50/1728 | 17503.75/230400 | 16073.64/460800 | 33.83/153.6 | 17.29/153.6 | 16.55/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 20.03 %    | 12.53 %     | 7.60 %          | 3.49 %          | 22.03 %     | 11.25 %     | 10.77 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 20) cost (throughput): ║ 4.6304 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.55 sec ║ total optimisation time: ║ 11.77 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.201491 (throughput) |    | 0.00/96      | 139.11/624 | 216.72/1728 | 17422.50/230400 | 16050.50/460800 | 33.83/153.6 | 17.28/153.6 | 16.55/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 22.29 %    | 12.54 %     | 7.56 %          | 3.48 %          | 22.02 %     | 11.25 %     | 10.77 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 21) cost (throughput): ║ 389864 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.49 sec ║ total optimisation time: ║ 12.26 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.201492 (throughput) |    | 0.00/96      | 139.11/624 | 216.72/1728 | 17429.17/230400 | 16065.08/460800 | 36.50/153.6 | 18.61/153.6 | 17.88/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 22.29 %    | 12.54 %     | 7.56 %          | 3.49 %          | 23.76 %     | 12.12 %     | 11.64 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 22) cost (throughput): ║ 4.6304 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.56 sec ║ total optimisation time: ║ 12.82 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.215141 (throughput) |    | 0.00/96      | 153.22/624 | 216.94/1728 | 17347.92/230400 | 16041.94/460800 | 36.49/153.6 | 18.61/153.6 | 17.88/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 24.55 %    | 12.55 %     | 7.53 %          | 3.48 %          | 23.76 %     | 12.12 %     | 11.64 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 23) cost (throughput): ║ 389864 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.39 sec ║ total optimisation time: ║ 13.21 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.215143 (throughput) |    | 0.00/96      | 153.22/624 | 216.94/1728 | 17354.58/230400 | 16056.53/460800 | 39.16/153.6 | 19.94/153.6 | 19.21/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 24.55 %    | 12.55 %     | 7.53 %          | 3.48 %          | 25.49 %     | 12.98 %     | 12.51 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 24) cost (throughput): ║ 295858 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.39 sec ║ total optimisation time: ║ 13.60 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.215145 (throughput) |    | 0.00/96      | 153.33/624 | 216.94/1728 | 17486.11/230400 | 16193.61/460800 | 40.83/153.6 | 21.28/153.6 | 19.55/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 24.57 %    | 12.55 %     | 7.59 %          | 3.51 %          | 26.58 %     | 13.85 %     | 12.73 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 25) cost (throughput): ║ 3.4378 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.59 sec ║ total optimisation time: ║ 14.19 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.217791 (throughput) |    | 0.00/96      | 163.89/624 | 217.00/1728 | 17493.33/230400 | 16200.75/460800 | 40.82/153.6 | 21.28/153.6 | 19.55/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 26.26 %    | 12.56 %     | 7.59 %          | 3.52 %          | 26.58 %     | 13.85 %     | 12.73 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦═════════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 26) cost (throughput): ║ 1.55039e+06 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.39 sec ║ total optimisation time: ║ 14.59 sec ║
# ╚═══════════════════════════════════════════════╩═════════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.217791 (throughput) |    | 0.00/96      | 163.89/624 | 217.00/1728 | 17500.00/230400 | 16215.33/460800 | 43.49/153.6 | 22.61/153.6 | 20.88/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 26.26 %    | 12.56 %     | 7.60 %          | 3.52 %          | 28.31 %     | 14.72 %     | 13.59 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 27) cost (throughput): ║ 3.4378 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.48 sec ║ total optimisation time: ║ 15.07 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.220502 (throughput) |    | 0.00/96      | 174.44/624 | 217.06/1728 | 17507.22/230400 | 16222.47/460800 | 43.49/153.6 | 22.61/153.6 | 20.88/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 27.96 %    | 12.56 %     | 7.60 %          | 3.52 %          | 28.31 %     | 14.72 %     | 13.59 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦═════════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 28) cost (throughput): ║ 1.55039e+06 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.49 sec ║ total optimisation time: ║ 15.56 sec ║
# ╚═══════════════════════════════════════════════╩═════════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.220503 (throughput) |    | 0.00/96      | 174.44/624 | 217.06/1728 | 17513.89/230400 | 16237.06/460800 | 46.15/153.6 | 23.94/153.6 | 22.21/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 27.96 %    | 12.56 %     | 7.60 %          | 3.52 %          | 30.05 %     | 15.59 %     | 14.46 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 29) cost (throughput): ║ 3.4378 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.52 sec ║ total optimisation time: ║ 16.08 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.223282 (throughput) |    | 0.00/96      | 185.00/624 | 217.11/1728 | 17521.11/230400 | 16244.19/460800 | 46.15/153.6 | 23.94/153.6 | 22.21/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 29.65 %    | 12.56 %     | 7.60 %          | 3.53 %          | 30.05 %     | 15.58 %     | 14.46 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦═════════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 30) cost (throughput): ║ 1.55039e+06 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.41 sec ║ total optimisation time: ║ 16.50 sec ║
# ╚═══════════════════════════════════════════════╩═════════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.223283 (throughput) |    | 0.00/96      | 185.00/624 | 217.11/1728 | 17527.78/230400 | 16258.78/460800 | 48.82/153.6 | 25.27/153.6 | 23.55/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 29.65 %    | 12.56 %     | 7.61 %          | 3.53 %          | 31.78 %     | 16.45 %     | 15.33 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 31) cost (throughput): ║ 943396 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.54 sec ║ total optimisation time: ║ 17.04 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.223284 (throughput) |    | 0.00/96      | 185.00/624 | 220.64/1728 | 20781.53/230400 | 16565.86/460800 | 50.54/153.6 | 26.65/153.6 | 23.89/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 29.65 %    | 12.77 %     | 9.02 %          | 3.60 %          | 32.90 %     | 17.35 %     | 15.55 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 32) cost (throughput): ║ 22202.5 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 1.04 sec ║ total optimisation time: ║ 18.08 sec ║
# ╚═══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.223543 (throughput) |    | 0.00/96      | 192.11/624 | 234.83/1728 | 24482.39/230400 | 19322.67/460800 | 50.63/153.6 | 26.65/153.6 | 23.98/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 30.79 %    | 13.59 %     | 10.63 %         | 4.19 %          | 32.96 %     | 17.35 %     | 15.61 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦═════════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 33) cost (throughput): ║ 6.06061e+06 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.42 sec ║ total optimisation time: ║ 18.50 sec ║
# ╚═══════════════════════════════════════════════╩═════════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.223543 (throughput) |    | 0.00/96      | 192.11/624 | 234.83/1728 | 24489.06/230400 | 19337.25/460800 | 53.30/153.6 | 27.98/153.6 | 25.31/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 30.79 %    | 13.59 %     | 10.63 %         | 4.20 %          | 34.70 %     | 18.22 %     | 16.48 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 34) cost (throughput): ║ 22202.5 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 1.03 sec ║ total optimisation time: ║ 19.54 sec ║
# ╚═══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.223803 (throughput) |    | 0.00/96      | 199.22/624 | 249.03/1728 | 28189.92/230400 | 22094.06/460800 | 53.39/153.6 | 27.98/153.6 | 25.40/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 31.93 %    | 14.41 %     | 12.24 %         | 4.79 %          | 34.76 %     | 18.22 %     | 16.54 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦═════════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 35) cost (throughput): ║ 6.06061e+06 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.43 sec ║ total optimisation time: ║ 19.96 sec ║
# ╚═══════════════════════════════════════════════╩═════════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.223804 (throughput) |    | 0.00/96      | 199.22/624 | 249.03/1728 | 28196.58/230400 | 22108.64/460800 | 56.05/153.6 | 29.32/153.6 | 26.74/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 31.93 %    | 14.41 %     | 12.24 %         | 4.80 %          | 36.49 %     | 19.09 %     | 17.41 %     | 0.00 %     |
#
# ╔═══════════════════════════════════════════════╦════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 36) cost (throughput): ║ 130039 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.54 sec ║ total optimisation time: ║ 20.51 sec ║
# ╚═══════════════════════════════════════════════╩════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.223808 (throughput) |    | 0.00/96      | 199.33/624 | 249.28/1728 | 28252.69/230400 | 22156.86/460800 | 56.05/153.6 | 29.32/153.6 | 26.74/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 31.94 %    | 14.43 %     | 12.26 %         | 4.81 %          | 36.49 %     | 19.09 %     | 17.41 %     | 0.00 %     |
#
# resolving memory bound partitions
# ||  Attemting Partition Merging:    ||  (Part 25, Part 26)    ||      ||  Total Partitions:    ||  36    ||
# create edge ('Conv_24', 'Relu_25')
# ╔═══════════════════════════════════════════════╦═══════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 25) cost (throughput): ║ 3.432 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.49 sec ║ total optimisation time: ║ 20.99 sec ║
# ╚═══════════════════════════════════════════════╩═══════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.227995 (throughput) |    | 0.00/96      | 205.03/624 | 256.40/1728 | 29053.06/230400 | 22774.91/460800 | 54.73/153.6 | 28.69/153.6 | 26.04/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 32.86 %    | 14.84 %     | 12.61 %         | 4.94 %          | 35.63 %     | 18.68 %     | 16.95 %     | 0.00 %     |
#
# ||  Outcome:    ||  Merge Accepted    ||
# ...
# ║ single partition (Part 3) cost (throughput): ║ 2160.04 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.85 sec ║ total optimisation time: ║ 32.60 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.317239 (throughput) |    | 0.00/96      | 324.90/624 | 370.35/1728 | 38970.15/230400 | 32900.85/460800 | 30.95/153.6 | 14.07/153.6 | 16.88/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 52.07 %    | 21.43 %     | 16.91 %         | 7.14 %          | 20.15 %     | 9.16 %      | 10.99 %     | 0.00 %     |
#
# ||  Outcome:    ||  Merge Accepted    ||
# ||  Attemting Partition Merging:    ||  (Part 3, Part 4)    ||      ||  Total Partitions:    ||  20    ||
# create edge ('Relu_6', 'Conv_7')
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 3) cost (throughput): ║ 1032.64 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 1.16 sec ║ total optimisation time: ║ 33.76 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.325737 (throughput) |    | 0.00/96      | 316.00/624 | 336.79/1728 | 36989.26/230400 | 31037.63/460800 | 32.14/153.6 | 14.58/153.6 | 17.56/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 50.64 %    | 19.49 %     | 16.05 %         | 6.74 %          | 20.93 %     | 9.49 %      | 11.43 %     | 0.00 %     |
#
# ||  Outcome:    ||  Merge Accepted    ||
# ||  Attemting Partition Merging:    ||  (Part 3, Part 4)    ||      ||  Total Partitions:    ||  19    ||
# create edge ('Conv_7', 'Relu_8')
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 3) cost (throughput): ║ 1124.77 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 1.05 sec ║ total optimisation time: ║ 34.81 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.334748 (throughput) |    | 0.00/96      | 333.56/624 | 355.50/1728 | 38940.17/230400 | 32628.50/460800 | 28.24/153.6 | 12.54/153.6 | 15.69/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 53.45 %    | 20.57 %     | 16.90 %         | 7.08 %          | 18.38 %     | 8.17 %      | 10.22 %     | 0.00 %     |
#
# ||  Outcome:    ||  Merge Accepted    ||
# ||  Attemting Partition Merging:    ||  (Part 3, Part 4)    ||      ||  Total Partitions:    ||  18    ||
# create edge ('Relu_8', 'MaxPool_9')
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 3) cost (throughput): ║ 1110.98 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 1.16 sec ║ total optimisation time: ║ 35.98 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.344262 (throughput) |    | 0.00/96      | 352.94/624 | 376.41/1728 | 40952.24/230400 | 34257.47/460800 | 26.10/153.6 | 10.27/153.6 | 15.83/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 56.56 %    | 21.78 %     | 17.77 %         | 7.43 %          | 16.99 %     | 6.69 %      | 10.31 %     | 0.00 %     |
#
# ||  Outcome:    ||  Merge Accepted    ||
# ||  Attemting Partition Merging:    ||  (Part 3, Part 4)    ||      ||  Total Partitions:    ||  17    ||
# create edge ('MaxPool_9', 'Conv_10')
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 3) cost (throughput): ║ 484.849 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 1.22 sec ║ total optimisation time: ║ 37.20 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |             |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|-------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN       | BW_OUT      | BW_WEIGHT  |
# | 0.354200 (throughput) |    | 0.00/96      | 341.50/624 | 309.94/1728 | 35724.88/230400 | 30161.19/460800 | 27.38/153.6 | 10.76/153.6 | 16.62/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 54.73 %    | 17.94 %     | 15.51 %         | 6.55 %          | 17.83 %     | 7.01 %      | 10.82 %     | 0.00 %     |
#
# ||  Outcome:    ||  Merge Accepted    ||
# ||  Attemting Partition Merging:    ||  (Part 2, Part 3)    ||      ||  Total Partitions:    ||  16    ||
# create edge ('Relu_1', 'Conv_2')
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 2) cost (throughput): ║ 484.844 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 1.30 sec ║ total optimisation time: ║ 38.50 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |            |             |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|------------|-------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN      | BW_OUT      | BW_WEIGHT  |
# | 0.364871 (throughput) |    | 0.00/96      | 364.27/624 | 330.60/1728 | 38090.53/230400 | 32136.93/460800 | 22.38/153.6 | 8.07/153.6 | 14.31/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 58.38 %    | 19.13 %     | 16.53 %         | 6.97 %          | 14.57 %     | 5.25 %     | 9.32 %      | 0.00 %     |
#
# ||  Outcome:    ||  Merge Accepted    ||
# ||  Attemting Partition Merging:    ||  (Part 1, Part 2)    ||      ||  Total Partitions:    ||  15    ||
# create edge ('Conv_0', 'Relu_1')
# ╔══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 1) cost (throughput): ║ 455.777 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 1.49 sec ║ total optimisation time: ║ 39.99 sec ║
# ╚══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |             |            |            |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|-------------|------------|------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW          | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.376186 (throughput) |    | 0.00/96      | 360.36/624 | 293.14/1728 | 38364.14/230400 | 31207.07/460800 | 16.27/153.6 | 8.25/153.6 | 8.02/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 57.75 %    | 16.96 %     | 16.65 %         | 6.77 %          | 10.59 %     | 5.37 %     | 5.22 %     | 0.00 %     |
#
# ||  Outcome:    ||  Merge Accepted    ||
# ||  Attemting Partition Merging:    ||  (Part 12, Part 13)    ||      ||  Total Partitions:    ||  14    ||
# create edge ('Gemm_34', 'Relu_35')
# ╔═══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 12) cost (throughput): ║ 22045.9 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.97 sec ║ total optimisation time: ║ 40.96 sec ║
# ╚═══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.388242 (throughput) |    | 0.00/96      | 388.08/624 | 315.69/1728 | 41334.92/230400 | 33650.69/460800 | 9.64/153.6 | 4.94/153.6 | 4.70/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 62.19 %    | 18.27 %     | 17.94 %         | 7.30 %          | 6.28 %     | 3.22 %     | 3.06 %     | 0.00 %     |
#
# ||  Outcome:    ||  Merge Accepted    ||
# ||  Attemting Partition Merging:    ||  (Part 12, Part 13)    ||      ||  Total Partitions:    ||  13    ||
# create edge ('Relu_35', 'Gemm_36')
# ╔═══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 12) cost (throughput): ║ 19727.8 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 1.14 sec ║ total optimisation time: ║ 42.10 sec ║
# ╚═══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.401097 (throughput) |    | 0.00/96      | 420.42/624 | 342.00/1728 | 45809.25/230400 | 36622.08/460800 | 9.91/153.6 | 5.09/153.6 | 4.82/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 67.37 %    | 19.79 %     | 19.88 %         | 7.95 %          | 6.45 %     | 3.31 %     | 3.14 %     | 0.00 %     |
#
# ||  Outcome:    ||  Merge Accepted    ||
# ||  Attemting Partition Merging:    ||  (Part 11, Part 12)    ||      ||  Total Partitions:    ||  12    ||
# create edge ('Relu_33', 'Gemm_34')
# ╔═══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 11) cost (throughput): ║ 24521.8 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 0.67 sec ║ total optimisation time: ║ 42.78 sec ║
# ╚═══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.414834 (throughput) |    | 0.00/96      | 477.00/624 | 349.64/1728 | 50522.73/230400 | 35613.27/460800 | 1.35/153.6 | 0.75/153.6 | 0.61/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 76.44 %    | 20.23 %     | 21.93 %         | 7.73 %          | 0.88 %     | 0.49 %     | 0.39 %     | 0.00 %     |
#
# ||  Outcome:    ||  Merge Accepted    ||
# ||  Attemting Partition Merging:    ||  (Part 10, Part 11)    ||      ||  Total Partitions:    ||  11    ||
# create edge ('Gemm_32', 'Relu_33')
# ╔═══════════════════════════════════════════════╦═════════╦══╦═══════════╦═══╦══════════════════════════════╦══════════╦══════════════════════════╦═══════════╗
# ║ single partition (Part 10) cost (throughput): ║ 5788.38 ║  ║ slowdown: ║ 1 ║ partition optimisation time: ║ 1.05 sec ║ total optimisation time: ║ 43.82 sec ║
# ╚═══════════════════════════════════════════════╩═════════╩══╩═══════════╩═══╩══════════════════════════════╩══════════╩══════════════════════════╩═══════════╝
# | COST:                 |    | RESOURCES:   |            |             |                 |                 |            |            |            |            |
# |-----------------------|----|--------------|------------|-------------|-----------------|-----------------|------------|------------|------------|------------|
# |                       |    | URAM         | BRAM       | DSP         | LUT             | FF              | BW         | BW_IN      | BW_OUT     | BW_WEIGHT  |
# | 0.429528 (throughput) |    | 0.00/96      | 510.20/624 | 345.80/1728 | 41908.40/230400 | 32222.10/460800 | 0.77/153.6 | 0.42/153.6 | 0.34/153.6 | 0.00/153.6 |
# |                       |    | 0.00 %       | 81.76 %    | 20.01 %     | 18.19 %         | 6.99 %          | 0.50 %     | 0.28 %     | 0.22 %     | 0.00 %     |
#
# ||  Outcome:    ||  Merge Accepted    ||

# %% [markdown]
# Note the choice of using which solver is actualy case by case.
