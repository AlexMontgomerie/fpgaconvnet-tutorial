# %% [markdown]
# # fpgaConvNet Optimiser Tutorial
#
# The [fpgaConvNet Optimiser](https://github.com/AlexMontgomerie/fpgaconvnet-optimiser) is the frontend for generating the dataflow hardware configuration for a given convolutional neural network. In this tutorial, The main aspects to this optimiser will be covered. A step by step guide of stages to the model to hardware description is given. Instructions on using the command-line interface are given towards the end.

# %%
# setup environment
# !python -m pip install --upgrade fpgaconvnet-optimiser-AlexMontgomerie==0.0.6
# !python -m pip install onnxruntime
# !wget https://www.dropbox.com/s/9ua1diq2fd254ab/lenet.onnx
# !mkdir figures
from IPython.display import Image
# Out:
# Requirement already satisfied: fpgaconvnet-optimiser-AlexMontgomerie==0.0.6 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (0.0.6)
# Requirement already satisfied: scipy>=1.2.1 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (1.5.2)
# Requirement already satisfied: torch>=1.7.1 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (1.7.1)
# Requirement already satisfied: onnx>=1.8.0 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (1.8.1)
# Requirement already satisfied: networkx>=2.5 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (2.5)
# Requirement already satisfied: pyyaml>=5.1.0 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (5.3.1)
# Requirement already satisfied: graphviz in /home/alex/.local/lib/python3.6/site-packages (from fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (0.13.2)
# Requirement already satisfied: numpy>=1.19.2 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (1.19.2)
# Requirement already satisfied: onnxruntime>=1.6.0 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (1.6.0)
# Requirement already satisfied: protobuf>=3.13.0 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (3.14.0)
# Requirement already satisfied: torchvision>=0.8.2 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (0.8.2)
# Requirement already satisfied: decorator>=4.3.0 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from networkx>=2.5->fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (4.4.2)
# Requirement already satisfied: six in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from onnx>=1.8.0->fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from onnx>=1.8.0->fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (3.7.4.3)
# Requirement already satisfied: dataclasses in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from torch>=1.7.1->fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (0.8)
# Requirement already satisfied: pillow>=4.1.1 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from torchvision>=0.8.2->fpgaconvnet-optimiser-AlexMontgomerie==0.0.6) (8.1.0)
# Requirement already satisfied: onnxruntime in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (1.6.0)
# Requirement already satisfied: protobuf in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from onnxruntime) (3.14.0)
# Requirement already satisfied: numpy>=1.16.6 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from onnxruntime) (1.19.2)
# Requirement already satisfied: six>=1.9 in /home/alex/miniconda3/envs/tmp/lib/python3.6/site-packages (from protobuf->onnxruntime) (1.15.0)
# --2021-02-21 18:55:37--  https://www.dropbox.com/s/9ua1diq2fd254ab/lenet.onnx
# Resolving www.dropbox.com (www.dropbox.com)... 2620:100:6020:18::a27d:4012, 162.125.64.18
# Connecting to www.dropbox.com (www.dropbox.com)|2620:100:6020:18::a27d:4012|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/9ua1diq2fd254ab/lenet.onnx [following]
# --2021-02-21 18:55:37--  https://www.dropbox.com/s/raw/9ua1diq2fd254ab/lenet.onnx
# Reusing existing connection to [www.dropbox.com]:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4a9b19341ef2707f66c861d5d0.dl.dropboxusercontent.com/cd/0/inline/BJZQc8IqzFTAPMFaH6RFK7ev2LB5wSFP7M0Ak0U81z3cu9oZmoElS3b6ft_kb4ejWMv113jk2XDVTdVf6vCHTWHLPJwbKhxOiqhbZ0OmxwkxQunqVhx_LWogc9Lh7cw7OgI/file# [following]
# --2021-02-21 18:55:37--  https://uc4a9b19341ef2707f66c861d5d0.dl.dropboxusercontent.com/cd/0/inline/BJZQc8IqzFTAPMFaH6RFK7ev2LB5wSFP7M0Ak0U81z3cu9oZmoElS3b6ft_kb4ejWMv113jk2XDVTdVf6vCHTWHLPJwbKhxOiqhbZ0OmxwkxQunqVhx_LWogc9Lh7cw7OgI/file
# Resolving uc4a9b19341ef2707f66c861d5d0.dl.dropboxusercontent.com (uc4a9b19341ef2707f66c861d5d0.dl.dropboxusercontent.com)... 2620:100:6020:15::a27d:400f, 162.125.64.15
# Connecting to uc4a9b19341ef2707f66c861d5d0.dl.dropboxusercontent.com (uc4a9b19341ef2707f66c861d5d0.dl.dropboxusercontent.com)|2620:100:6020:15::a27d:400f|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BJbSyD6NyczLe-PXoaizAf11jel8fh3C9BGxyWIUw_IGOOyzvt9jhomvZvxUN6f-X8H1CQEkgTRtB9c7bSoki9InzCeWFPqu284hG-XOndN-UdFz_ubqv6VXKpnwOLrv311DcNbwm_pV8qJs44YgkIECG4sbSeSzd2W8p-LiQq7Qo5ifTjwEEQmzl606ASWaYHTSrTn6WCuo4ONZfkvtGZH3hSCswJeyQ4kYd6M3REpblYCpcy6ofhn-8XYRCgmGScCNIinTQexco6L_xSwiwfxeKTxTEM1EdiTW3ZNUBEjgBYCjF3XEF4kHHU1sjidBCqWmE6TZdhVPLoJdL9W-R-BUDDFnZ1MyqvhOXaqcpDT-aw/file [following]
# --2021-02-21 18:55:38--  https://uc4a9b19341ef2707f66c861d5d0.dl.dropboxusercontent.com/cd/0/inline2/BJbSyD6NyczLe-PXoaizAf11jel8fh3C9BGxyWIUw_IGOOyzvt9jhomvZvxUN6f-X8H1CQEkgTRtB9c7bSoki9InzCeWFPqu284hG-XOndN-UdFz_ubqv6VXKpnwOLrv311DcNbwm_pV8qJs44YgkIECG4sbSeSzd2W8p-LiQq7Qo5ifTjwEEQmzl606ASWaYHTSrTn6WCuo4ONZfkvtGZH3hSCswJeyQ4kYd6M3REpblYCpcy6ofhn-8XYRCgmGScCNIinTQexco6L_xSwiwfxeKTxTEM1EdiTW3ZNUBEjgBYCjF3XEF4kHHU1sjidBCqWmE6TZdhVPLoJdL9W-R-BUDDFnZ1MyqvhOXaqcpDT-aw/file
# Reusing existing connection to [uc4a9b19341ef2707f66c861d5d0.dl.dropboxusercontent.com]:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1726355 (1.6M) [application/octet-stream]
# Saving to: 'lenet.onnx.12'
#
# lenet.onnx.12       100%[===================>]   1.65M  --.-KB/s    in 0.09s
#
# 2021-02-21 18:55:39 (17.5 MB/s) - 'lenet.onnx.12' saved [1726355/1726355]
#
# mkdir: cannot create directory 'figures': File exists

# %% [markdown]
# ## 1. Initialising a Hardware Model
#
# The first step is parsing the CNN model into an initial hardware model. This initial hardware model is a very basic implementation, which maps the CNN layers to their hardware equivalent. There is no parallelism in this intial model, and serves as a baseline for a feasible hardware implementation.

# %% [markdown]
# To initialise the hardware model, a `Network` class is from the given network description. In this tutorial, the [LeNet]() CNN model is used.

# %%
from fpgaconvnet_optimiser.models.network import Network

# create network
lenet = Network("lenet", "lenet.onnx")
lenet.update_partitions()
# Out:
# {'rows_in': 12, 'cols_in': 12, 'channels_in': 20, 'rows_out': 8, 'cols_out': 8, 'channels_out': 50, 'coarse_in': 1, 'coarse_out': 1, 'filters': 50, 'pad': 0, 'pad_top': 0, 'pad_right': 0, 'pad_bottom': 0, 'pad_left': 0, 'stride': 1, 'groups': 1, 'kernel_size': 5, 'fine': 1, 'buffer_depth': 0, 'batch_size': 1}

# %% [markdown]
# We have now initialised the hardware model, however it doesn't have knowledge of the hardware constraints. We can do this by uploading a platform configuration file.

# %%
# give hardware model a platform configuration
lenet.update_platform("zedboard.json")

# get resource and performance estimates
print("latency (ms): ", lenet.get_latency())
print("throughput (fps): ", lenet.get_throughput())

# visualise network
lenet.visualise("figures/lenet_baseline.png")
Image(filename="figures/lenet_baseline.png")
# Out:
# latency (ms):  0.016068288
# throughput (fps):  62.234383650579325

# %% [markdown]
# ## 2. Transforms
#
# So far we have an initial hardware model, but with very poor performance. The next step is performing optimisations to better map the CNN model to the hardware.

# %% [markdown]
# ### 2.1 Partitioning
#
# The first transform we are going to apply is partitioning. The partitioning transform can split the computation graph into seperate subgraphs. At runtime, these subgraphs are run sequentially by re-programming the device. The purpose of this transform is to reduce resource usage for a given partition.

# %% [markdown]
# First, all the available graph splits can be shown. There are two types of splits: vertical and horizontal. Horizontial splits two sequential nodes, and vertical splits a parallel path of computation.

# %%
# get all avaiable partitions
print("all horizontal splits: ", lenet.get_all_horizontal_splits(0))
# Out:
# all horizontal splits:  [('conv1', 'pool1'), ('pool1', 'conv2'), ('conv2', 'pool2'), ('pool2', 'ip1_6relu1'), ('ip1_6relu1', 'ip1'), ('ip1', 'ip2')]

# %% [markdown]
# A split between the `pool2` node and the `ip1_6relu1` node is applied, seperating the original network into two seperate partitions.

# %%
# split all partitions
lenet.split_horizontal(0,("pool2","ip1_6relu1"))

# visualise network
lenet.visualise("figures/lenet_partitioned.png")
Image(filename="figures/lenet_partitioned.png")

# %% [markdown]
# ### Fine Folding
#
# The next transform introduced is fine-grain folding. This transform is applied to the `Conv` module, and defines the degree of parallelism at the kernel level. Essentially, the fine factor dictates the number of multipliers used in the dot-product computation.

# %% [markdown]
# This transform trades of resource usage with performance. Let's first see what our baseline resource and performance is. Latency describes the number of clock cycles needed to compute the given node.

# %%
# show rates before
print(f"latency conv1 (fine = {lenet.partitions[0].graph.nodes['conv1']['hw'].fine}) : {lenet.partitions[0].graph.nodes['conv1']['hw'].get_latency()}")
print(f"latency conv2 (fine = {lenet.partitions[0].graph.nodes['conv2']['hw'].fine}) : {lenet.partitions[0].graph.nodes['conv2']['hw'].get_latency()}")
print("\n")

# show resource usage before
print(f"conv1 resource usage : {lenet.partitions[0].graph.nodes['conv1']['hw'].resource()}")
print(f"conv2 resource usage : {lenet.partitions[0].graph.nodes['conv2']['hw'].resource()}")
# Out:
# latency conv1 (fine = 1) : 288000.0
# latency conv2 (fine = 1) : 1599999.9999999998
#
#
# conv1 resource usage : {'LUT': 0, 'FF': 0, 'BRAM': 25, 'DSP': 1}
# conv2 resource usage : {'LUT': 0, 'FF': 0, 'BRAM': 27, 'DSP': 1}

# %% [markdown]
# We can see that there is very little resource usage but also poor performance. Let's next see what fine-grain folding factors we can apply to the network.

# %%
# get possible fine factors
print("possible fine (conv1): ", lenet.partitions[0].graph.nodes['conv1']['hw'].get_fine_feasible())
print("possible fine (conv2): ", lenet.partitions[0].graph.nodes['conv2']['hw'].get_fine_feasible())
# Out:
# possible fine (conv1):  [1, 5, 25]
# possible fine (conv2):  [1, 5, 25]

# %% [markdown]
# The fine-grain folding factors are factors of the kernel size. Finally, lets apply the maximum fine-grain folding factor and see how this impacts performance and resources.

# %%
# update fine factors
lenet.partitions[0].graph.nodes['conv1']['hw'].fine = 25
lenet.partitions[0].graph.nodes['conv2']['hw'].fine = 25
lenet.update_partitions()

# show updated rates
print(f"latency conv1 (fine = {lenet.partitions[0].graph.nodes['conv1']['hw'].fine}) : {lenet.partitions[0].graph.nodes['conv1']['hw'].get_latency()}")
print(f"latency conv2 (fine = {lenet.partitions[0].graph.nodes['conv2']['hw'].fine}) : {lenet.partitions[0].graph.nodes['conv2']['hw'].get_latency()}")
print("\n")

# show updated resource usage
print(f"conv1 resource usage : {lenet.partitions[0].graph.nodes['conv1']['hw'].resource()}")
print(f"conv2 resource usage : {lenet.partitions[0].graph.nodes['conv2']['hw'].resource()}")
# Out:
# latency conv1 (fine = 25) : 11520.000000000002
# latency conv2 (fine = 25) : 64000.0
#
#
# conv1 resource usage : {'LUT': 0, 'FF': 0, 'BRAM': 49, 'DSP': 25}
# conv2 resource usage : {'LUT': 0, 'FF': 0, 'BRAM': 51, 'DSP': 25}
# {'rows_in': 12, 'cols_in': 12, 'channels_in': 20, 'rows_out': 8, 'cols_out': 8, 'channels_out': 50, 'coarse_in': 1, 'coarse_out': 1, 'filters': 50, 'pad': 0, 'pad_top': 0, 'pad_right': 0, 'pad_bottom': 0, 'pad_left': 0, 'stride': 1, 'groups': 1, 'kernel_size': 5, 'fine': 25, 'buffer_depth': 0, 'batch_size': 1}

# %% [markdown]
# It is worth pointing out that this transform also affects `BRAM` usage, as more multipliers require more `BRAM` ports to read the filter coefficients.

# %% [markdown]
# ### Coarse Folding
#
# The coarse folding transform defines parallelism across the channel and filter dimensions. It tells us the number of parallel streams in and out of the device.

# %% [markdown]
# Let's change the coarse grain folding factor for different layers in first partition. The `conv1`, `pool1`, `conv2` layers are updated.

# %%
# update coarse factors

## conv1
lenet.partitions[0].graph.nodes['conv1']['hw'].update_coarse_out(5)

## pool1
lenet.partitions[0].graph.nodes['pool1']['hw'].update_coarse_in(5)

## conv2
lenet.partitions[0].graph.nodes['conv2']['hw'].update_coarse_in(5)
lenet.partitions[0].graph.nodes['conv2']['hw'].update_coarse_out(10)

## pool2
lenet.partitions[0].graph.nodes['pool2']['hw'].update_coarse_in(10)

lenet.update_partitions()

# visualise network
lenet.visualise("figures/lenet_coarse.png")
Image(filename="figures/lenet_coarse.png")
# Out:
# {'rows_in': 12, 'cols_in': 12, 'channels_in': 20, 'rows_out': 8, 'cols_out': 8, 'channels_out': 50, 'coarse_in': 5, 'coarse_out': 10, 'filters': 50, 'pad': 0, 'pad_top': 0, 'pad_right': 0, 'pad_bottom': 0, 'pad_left': 0, 'stride': 1, 'groups': 1, 'kernel_size': 5, 'fine': 25, 'buffer_depth': 0, 'batch_size': 1}

# %% [markdown]
# We can see that the coarse factors lead to duplication of modules within the layer, allowing for this parallelism. It's worth noting that there are restrictions on the coarse factors. For example, Pooling layers must have the same input and output coarse factor. `Squeeze` layers are added to allow for difference in two sequential coarse factors.

# %% [markdown]
# ### Weights Reloading
#
# The final transform we will look at is the weights reloading transform. For dataflow-driven CNN accelerators, on-chip memory becomes a significant bottleneck as filter coefficients are stored on-chip. The weights reloading transform addresses this problem by reducing the number of filters stored in each partition.

# %% [markdown]
# First, lets see what resources we have before weights reloading is applied, as well as the dimensions of the last layer in partition 0.

# %%
# resources before
print("resource usage: ", lenet.partitions[0].get_resource_usage())

# layer info of last layer
import fpgaconvnet_optimiser.tools.graphs as graphs
output_node = lenet.partitions[0].output_nodes[0]
print("conv2 filters: ", lenet.partitions[0].graph.nodes["conv2"]["hw"].filters)
# Out:
# resource usage:  {'FF': 0, 'LUT': 0, 'DSP': 1377, 'BRAM': 2476}
# conv2 filters:  50
